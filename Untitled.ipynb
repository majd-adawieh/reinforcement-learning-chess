# %%
import numpy as np
import matplotlib.pyplot as plt


category_names = ['Multi-agent win', 'Single-agent win', "Draw"]
results = {
    'DQN vs DQN': [95, 94, 11],
    'DQN vs Double DQN': [96, 97, 7],
    'DQN vs Duelling DQN': [88, 101, 11],
    
    'Double DQN vs DQN': [90, 95, 15],
    'Double DQN vs Double DQN': [92, 93, 15],
    'Double DQN vs Duelling DQN': [88, 89, 23],
    
    'Duelling DQN vs DQN': [91, 105, 4],
    'Duelling DQN vs Double DQN': [92, 94, 14],
    'Duelling DQN vs Duelling DQN': [96, 91, 13],
}


def survey(results, category_names):
    labels = list(results.keys())
    data = np.array(list(results.values()))
    data_cum = data.cumsum(axis=1)
    category_colors = plt.colormaps['RdYlGn'](
        np.linspace(0.15, 0.85, data.shape[1]))

    fig, ax = plt.subplots(figsize=(21,10))
    ax.invert_yaxis()
    ax.xaxis.set_visible(False)
    ax.set_xlim(0, np.sum(data, axis=1).max())

    for i, (colname, color) in enumerate(zip(category_names, category_colors)):
        widths = data[:, i]
        starts = data_cum[:, i] - widths
        rects = ax.barh(labels, widths, left=starts, height=0.5,
                        label=colname, color=color)

        r, g, b, _ = color
        text_color = 'white' if r * g * b < 0.5 else 'darkgrey'
        ax.bar_label(rects, label_type='center', color=text_color)
    ax.legend(ncol=len(category_names), bbox_to_anchor=(0, 1),
              loc='lower left', fontsize='large')

    return fig, ax


survey(results, category_names)
plt.savefig("results1.pdf",dpi=600,bbox_inches = 'tight',pad_inches = 0.1)
plt.show()

# %%
import pandas as pd

# %%
loss_single_duelling = pd.read_csv('./metrices/one-agent-duelling-q-learning-loss')
reward_single_duelling = pd.read_csv("./metrices/one-agent-duelling-q-learning-reward")
duration_single_duelling = pd.read_csv("./metrices/one-agent-duelling-q-learning-duration")

loss_single_double = pd.read_csv('./metrices/one-agent-double-q-learning-loss')
reward_single_double = pd.read_csv("./metrices/one-agent-double-q-learning-reward")
duration_single_double = pd.read_csv("./metrices/one-agent-double-q-learning-duration")

loss_single_dqn = pd.read_csv('./metrices/one-agent-deep-q-learning-loss')
reward_single_dqn = pd.read_csv("./metrices/one-agent-deep-q-learning-reward")
duration_single_dqn = pd.read_csv("./metrices/one-agent-deep-q-learning-duration")


loss_multi_double = pd.read_csv('./metrices/multi-agent-double-q-learning-loss')
reward_multi_double = pd.read_csv("./metrices/multi-agent-double-q-learning-reward")
duration_multi_double = pd.read_csv("./metrices/multi-agent-double-q-learning-duration")

loss_multi_dqn = pd.read_csv('./metrices/multi-agent-deep-q-learning-loss')
reward_multi_dqn = pd.read_csv("./metrices/multi-agent-deep-q-learning-reward")
duration_multi_dqn = pd.read_csv("./metrices/multi-agent-deep-q-learning-duration")

# %%
duration_single_duelling
# Out:
#          ID  Game duration
# 0         1             15
# 1         2              4
# 2         3              8
# 3         4              4
# 4         5              4
# ...     ...            ...
# 9995   9996             11
# 9996   9997              4
# 9997   9998             21
# 9998   9999              5
# 9999  10000             12
#
# [10000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt 

def plot_stats(stats):
    rows = len(stats)
    cols = 1

    fig, ax = plt.subplots(rows, cols, figsize=(20, 25))

    for i, key in enumerate(stats):
        vals = stats[key]
        #vals = [np.mean(vals[i-10:i+10]) for i in range(10, len(vals)-10)]
        if len(stats) > 1:
            ax[i].plot(range(len(vals)), vals)
            ax[i].set_title(key, size=18)
        else:
            ax.plot(range(len(vals)), vals)
            ax.set_title(key, size=18)
    plt.tight_layout()
    plt.savefig("results.pdf",dpi=600,bbox_inches = 'tight',pad_inches = 0.1)
    plt.show()

# %%
stats = {
    "one-agent-duelling-q-learning-loss": loss_single_duelling["MSE Loss"].to_numpy(),
    "one-agent-duelling-q-learning-reward": reward_single_duelling["Returns"].to_numpy(),
    "one-agent-duelling-q-learning-duration": duration_single_duelling["Game duration"].to_numpy(),
    
    "one-agent-double-q-learning-loss": loss_single_double["MSE Loss"].to_numpy(),
    "one-agent-double-q-learning-reward": reward_single_double["Returns"].to_numpy(),
    "one-agent-double-q-learning-duration": duration_single_double["Game duration"].to_numpy(),
    
    "one-agent-deep-q-learning-loss": loss_single_dqn["MSE Loss"].to_numpy(),
    "one-agent-deep-q-learning-reward": reward_single_dqn["Returns"].to_numpy(),
    "one-agent-deep-q-learning-duration": duration_single_dqn["Game duration"].to_numpy(),
    
    "multi-agent-double-q-learning-loss": loss_multi_double["MSE Loss"].to_numpy(),
    "multi-agent-double-q-learning-reward": reward_multi_double["Returns"].to_numpy(),
    "multi-agent-double-q-learning-duration": duration_multi_double["Game duration"].to_numpy(),
    
    "multi-agent-deep-q-learning-loss": loss_multi_dqn["MSE Loss"].to_numpy(),
    "multi-agent-deep-q-learning-reward": reward_multi_dqn["Returns"].to_numpy(),
    "multi-agent-deep-q-learning-duration": duration_multi_dqn["Game duration"].to_numpy(),
}

# %%
plot_stats(stats)
